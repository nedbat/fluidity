# %%
from drawing import svg_row
from fluidity import Fluidity, LinearNoise
f = Fluidity(LinearNoise(seed=9, istep=0.003), npoints=10, nlines=1)
f1 = f.tweak(one_order=True)
svg_row(f.draw(size=(400,400)), f1.draw(size=(400, 400)))
# Out:
# <div style="display:flex; flex-direction: row; justify-content: space-evenly"><?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="400px" height="400px" viewBox="0 0 400 400">
# ...

# %%
svg_row(
    *[Fluidity(LinearNoise(seed=s, istep=0.003), npoints=10, nlines=1).draw(size=(200,200)) for s in range(5)]
)
# Out:
# <div style="display:flex; flex-direction: row; justify-content: space-evenly"><?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="200px" height="200px" viewBox="0 0 200 200">
# ...

# %%
svg_row(
    *[Fluidity(LinearNoise(seed=s+10, istep=0.003), npoints=10, nlines=1).draw(size=(200,200)) for s in range(5)]
)
# Out:
# <div style="display:flex; flex-direction: row; justify-content: space-evenly"><?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="200px" height="200px" viewBox="0 0 200 200">
# ...

# %%
svg_row(
    *[Fluidity(LinearNoise(seed=s+20, istep=0.003), npoints=10, nlines=1).draw(size=(200,200)) for s in range(5)]
)
# Out:
# <div style="display:flex; flex-direction: row; justify-content: space-evenly"><?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="200px" height="200px" viewBox="0 0 200 200">
# ...

# %%
Fluidity(LinearNoise(seed=55, istep=0.003, istart=0.07), npoints=15, nlines=50, one_order=True).draw(size=(800, 800))

# %%
f.bbox()
# Out:
# [-0.212, -0.195, 1.263, 1.363]

# %%
[-0.006, -0.164, 1.047, 1.369]
# Out:
# [-0.006, -0.164, 1.047, 1.369]
