# %%
from fluidity import Fluidity
f = Fluidity(seed=5572, npoints=15, nlines=50, ystep=0.003)
f.draw(size=(400, 400))

# %%
f1 = f.tweak(one_order=True)
f1.draw(size=(400, 400))

# %%
f.bbox()
# Out:
# [(-1.8066251957011146, -2.5308047623870054),
#  (2.6502102559583762, 1.3968130039728068)]

# %%
f1.bbox()
# Out:
# [(-1.1619591338692143, -1.6397630849588638),
#  (1.5696806693332128, 1.3968130039728068)]
